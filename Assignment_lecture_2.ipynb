# %% [markdown]
# <a href="https://colab.research.google.com/github/ashu433/shala2020.github.io/blob/master/Assignment_lecture_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_movies=pd.read_csv("moviesData_1.csv")
df_train=pd.read_csv("train.csv")
df_movies.head(10)
# Out:
#    Unnamed: 0                   title    title_type        genre  runtime  \
# 0           1             Filly Brown  Feature Film        Drama     80.0
# 1           2                The Dish  Feature Film        Drama    101.0
# 2           3     Waiting for Guffman  Feature Film       Comedy     84.0
# 3           4    The Age of Innocence  Feature Film        Drama    139.0
# 4           5             Malevolence  Feature Film       Horror     90.0
# 5           6             Old Partner   Documentary  Documentary     78.0
# 6           7               Lady Jane  Feature Film        Drama    142.0
# 7           8            Mad Dog Time  Feature Film        Drama     93.0
# 8           9  Beauty Is Embarrassing   Documentary  Documentary     88.0
# 9          10    The Snowtown Murders  Feature Film        Drama    119.0
#
#   mpaa_rating                    studio  thtr_rel_year  thtr_rel_month  \
# 0           R       Indomina Media Inc.           2013               4
# ...

# %%
column_names = df_movies.columns.tolist()
column_names
# Out:
# ['Unnamed: 0',
#  'title',
#  'title_type',
#  'genre',
#  'runtime',
#  'mpaa_rating',
#  'studio',
#  'thtr_rel_year',
#  'thtr_rel_month',
#  'thtr_rel_day',
#  'dvd_rel_year',
#  'dvd_rel_month',
#  'dvd_rel_day',
#  'imdb_rating',
#  'imdb_num_votes',
#  'critics_rating',
#  'critics_score',
#  'audience_rating',
#  'audience_score',
#  'best_pic_nom',
#  'best_pic_win',
#  'best_actor_win',
#  'best_actress_win',
#  'best_dir_win',
#  'top200_box',
#  'director',
#  'actor1',
#  'actor2',
#  'actor3',
#  'actor4',
#  'actor5']

# %%
column_names = df_train.columns.tolist()
column_names
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'ID']

# %%
print(df_train["MonthlyRate"].max())
print(df_train["MonthlyRate"].min())
print(df_train["MonthlyRate"].mean())
# Out:
# 26999
# 2094
# 14243.53112840467

# %%
df_train.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1028.000000  1028.000000  1028.000000       1028.000000  1028.000000
# mean     36.999027     0.167315   806.551556          9.010700     2.873541
# std       9.444297     0.373439   407.043735          8.078418     1.032840
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.750000          2.000000     2.000000
# 50%      36.000000     0.000000   813.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.250000         13.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1028.0     1028.000000              1028.000000  1028.000000
# mean             1.0      710.198444                 2.719844    65.451362
# ...

# %%
df_train["MonthlyRate"].describe()
# Out:
# count     1028.000000
# mean     14243.531128
# std       7048.768076
# min       2094.000000
# 25%       8259.750000
# 50%      14074.500000
# 75%      20342.250000
# max      26999.000000
# Name: MonthlyRate, dtype: float64

# %%
df_train.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# ...

# %%
df_movies.isnull().sum()
# Out:
# Unnamed: 0           0
# title                0
# title_type           0
# genre                0
# runtime              1
# mpaa_rating          0
# studio               5
# thtr_rel_year        0
# thtr_rel_month       0
# thtr_rel_day         0
# dvd_rel_year         7
# dvd_rel_month        7
# dvd_rel_day          7
# imdb_rating          0
# imdb_num_votes       0
# critics_rating       0
# critics_score        0
# audience_rating      0
# audience_score       0
# best_pic_nom         0
# best_pic_win         0
# best_actor_win       0
# best_actress_win     0
# best_dir_win         0
# top200_box           0
# director             2
# actor1               2
# actor2               7
# actor3               9
# actor4              12
# actor5              14
# dtype: int64

# %%
mean_value=df_movies["runtime"].mean()
df_movies["runtime"].fillna(mean_value,inplace=True)

# %%
df_movies.isnull().sum()
# Out:
# Unnamed: 0           0
# title                0
# title_type           0
# genre                0
# runtime              0
# mpaa_rating          0
# studio               5
# thtr_rel_year        0
# thtr_rel_month       0
# thtr_rel_day         0
# dvd_rel_year         7
# dvd_rel_month        7
# dvd_rel_day          7
# imdb_rating          0
# imdb_num_votes       0
# critics_rating       0
# critics_score        0
# audience_rating      0
# audience_score       0
# best_pic_nom         0
# best_pic_win         0
# best_actor_win       0
# best_actress_win     0
# best_dir_win         0
# top200_box           0
# director             2
# actor1               2
# actor2               7
# actor3               9
# actor4              12
# actor5              14
# dtype: int64

# %%
df_movies.shape
# Out:
# (600, 31)

# %%
df_movies=df_movies.dropna()

# %%
df_movies.shape
# Out:
# (572, 31)

# %%
df_movies.isnull().sum()
# Out:
# Unnamed: 0          0
# title               0
# title_type          0
# genre               0
# runtime             0
# mpaa_rating         0
# studio              0
# thtr_rel_year       0
# thtr_rel_month      0
# thtr_rel_day        0
# dvd_rel_year        0
# dvd_rel_month       0
# dvd_rel_day         0
# imdb_rating         0
# imdb_num_votes      0
# critics_rating      0
# critics_score       0
# audience_rating     0
# audience_score      0
# best_pic_nom        0
# best_pic_win        0
# best_actor_win      0
# best_actress_win    0
# best_dir_win        0
# top200_box          0
# director            0
# actor1              0
# actor2              0
# actor3              0
# actor4              0
# actor5              0
# dtype: int64

# %%
df_train["MonthelyRateNew"]=(df_train['MonthlyRate']-df_train['MonthlyRate'].mean())/df_train['MonthlyRate'].std()

# %%
df_train["MonthelyRateNew"]
# Out:
# 0       0.742749
# 1       1.512813
# 2      -1.680795
# 3       1.264827
# 4       0.338849
#           ...
# 1023   -0.531941
# 1024    1.767609
# 1025    0.137254
# 1026    1.290930
# 1027   -1.494663
# Name: MonthelyRateNew, Length: 1028, dtype: float64

# %%
df_movies["dvd_rel_day"].head()
# Out:
# 0    30.0
# 1    28.0
# 2    21.0
# 3     6.0
# 4    19.0
# Name: dvd_rel_day, dtype: float64

# %%
plt.hist(df_train['Age'],bins=30,edgecolor='black')
plt.show()

# %%
df_train['Attrition']
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1023    0
# 1024    0
# 1025    0
# 1026    0
# 1027    0
# Name: Attrition, Length: 1028, dtype: int64

# %%
plt.scatter(df_train['Age'],df_train['Attrition'],c='red',edgecolors='black')
plt.show()

# %%
df_old=df_train[df_train['Age']>=50]

# %%
df_old=df_old.reset_index(drop=True)
df_old
# Out:
#      Age  Attrition BusinessTravel  DailyRate              Department  \
# 0     59          0  Travel_Rarely       1324  Research & Development
# 1     53          0  Travel_Rarely       1219                   Sales
# 2     53          0  Travel_Rarely       1282  Research & Development
# 3     50          1  Travel_Rarely        869                   Sales
# 4     50          0  Travel_Rarely        989  Research & Development
# ..   ...        ...            ...        ...                     ...
# 135   52          0  Travel_Rarely        258  Research & Development
# 136   54          0  Travel_Rarely        971  Research & Development
# 137   58          0  Travel_Rarely       1055  Research & Development
# 138   55          0  Travel_Rarely       1136  Research & Development
# 139   56          0  Travel_Rarely       1255  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
Atteretion=df_old[df_old["Attrition"]==1]
Atteretion
# Out:
#      Age  Attrition     BusinessTravel  DailyRate              Department  \
# 3     50          1      Travel_Rarely        869                   Sales
# 18    56          1      Travel_Rarely        441  Research & Development
# 20    58          1      Travel_Rarely        147  Research & Development
# 22    51          1  Travel_Frequently       1150  Research & Development
# 48    52          1      Travel_Rarely        723  Research & Development
# 69    50          1  Travel_Frequently        562                   Sales
# 76    55          1      Travel_Rarely        725  Research & Development
# 81    58          1      Travel_Rarely        286  Research & Development
# 82    55          1      Travel_Rarely        436                   Sales
# 89    58          1  Travel_Frequently        781  Research & Development
# 92    58          1      Travel_Rarely        289  Research & Development
# 100   52          1      Travel_Rarely        266                   Sales
# ...

# %%
Atteretion.shape[0]/df_old.shape[0]
# Out:
# 0.12142857142857143

# %%
df_train['Attrition'].value_counts()
# Out:
# 0    856
# 1    172
# Name: Attrition, dtype: int64

# %%
sns.countplot(x="Attrition",data=df_train,hue='Age')
plt.show()

# %%
sns.countplot(x="Attrition",data=df_train,hue='Gender')
plt.show()

# %%
cross_tab=pd.crosstab(df_train['BusinessTravel'],df_train['Attrition'])
cross_tab
# Out:
# Attrition            0    1
# BusinessTravel
# Non-Travel          92   10
# Travel_Frequently  150   47
# Travel_Rarely      614  115

# %%
pd.crosstab(df_train['BusinessTravel'],df_train['Attrition']).plot(kind='bar')
plt.show()

# %%
cross_tab.plot(kind='bar',stacked=True,edgecolor='black')
plt.show()

# %%
plt.hist(df_train["TotalWorkingYears"],bins=30,edgecolor='black')
plt.xlabel("Total Working years")
plt.ylabel("frequency")
plt.show()

# %%
plt.hist(df_train["YearsAtCompany"],bins=30,edgecolor='black')
plt.xlabel("Total years in the company")
plt.ylabel("frequency")
plt.show()

# %%
sns.boxplot(x='Department',y='MonthlyIncome',data=df_train)
plt.show()

# %%
job_role_count=df_train['JobRole'].value_counts()
plt.pie(job_role_count,labels=job_role_count.index.to_list())
plt.show()

# %%
plt.figure(figsize=(10,10))
mask = np.triu(df_movies.corr(),k=1)
sns.heatmap(df_movies.corr(),annot=True, cmap="coolwarm", mask=mask)
plt.show()
# Out:
# <ipython-input-309-62c8773fa909>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mask = np.triu(df_movies.corr(),k=1)
# <ipython-input-309-62c8773fa909>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_movies.corr(),annot=True, cmap="coolwarm", mask=mask)
