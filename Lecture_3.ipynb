# %% [markdown]
# <a href="https://colab.research.google.com/github/ashu433/shala2020.github.io/blob/master/Lecture_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading the packages
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# http://python-graph-gallery.com/barplot/
# https://matplotlib.org/tutorials/introductory/pyplot.html
# Make a fake dataset:
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')

# Create bars
plt.bar(bars, height)

# Create names on the x-axis
plt.xticks(bars)

# Show graphic
plt.show()

# %%
# Create horizontal bars
plt.barh(bars, height)

# Create names on the y-axis
plt.yticks(bars)

# Show graphic
plt.show()

# %%
# RGB is a way of making colors.
# color =  red, green and blue + the transparency
# Put transparency = 0
# Put transparency = 1
plt.bar(bars, height, color=(0.2, 0.4, 0.6, 0.6))
plt.xticks(bars)
plt.show()

# %%
# Different color for each bar
# Provide a list of color names to the color argument
plt.bar(bars, height, color=['black', 'red', 'green', 'blue', 'cyan'])
plt.xticks(bars)
plt.show()

# %%
# Control color of the border
# The edgecolor argument allows to color the borders of barplots.
plt.bar(bars, height, color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.xticks(bars)
plt.show()

# %%
# Create bars and choose color
plt.bar(bars, height, color = (0.5,0.1,0.5,0.6))

# Add title and axis names
plt.title('Height', fontsize=14)
plt.xlabel('Name', fontsize=14)
plt.ylabel('Height', fontsize=14)

# Limits for the Y axis
plt.ylim(0,60)

# Create names
plt.xticks(bars)

# Show graphic
plt.show()

# %%
df = pd.DataFrame({'year': [2015, 2016, 2017, 2018, 2019], 'T20': [24, 36, 12, 18, 25], 'ODI': [89, 24, 37, 63, 98]})

# Draw the plot
plt.plot( 'year', 'T20', data = df)
plt.show()

# %%
# Draw the plot
# https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.legend.html
plt.plot( 'year', 'T20', data = df, linewidth = 5)
plt.plot('year', 'ODI', data = df, c='red', linewidth = 5)
plt.xticks(np.arange(min(df.year), max(df.year)+1, 1.0), fontsize = 15)
plt.yticks(np.arange(0,125,25), fontsize = 15)
plt.title('Points scored by India', fontsize = 15)
plt.xlabel('Year', fontsize = 15)
plt.ylabel('Points', fontsize = 15)
plt.legend(loc='upper center')
plt.grid(b=True, alpha=0.9) #which argument to choose the axis
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-504d49e706e0> in <cell line: 11>()
#       9 plt.ylabel('Points', fontsize = 15)
#      10 plt.legend(loc='upper center')
# ---> 11 plt.grid(b=True, alpha=0.9) #which argument to choose the axis
#      12 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in grid(visible, which, axis, **kwargs)
#    2614 @_copy_docstring_and_deprecators(Axes.grid)
#    2615 def grid(visible=None, which='major', axis='both', **kwargs):
# -> 2616     return gca().grid(visible=visible, which=which, axis=axis, **kwargs)
#    2617
#    2618
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in grid(self, visible, which, axis, **kwargs)
#    3192         _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193         if axis in ['x', 'both']:
# -> 3194             self.xaxis.grid(visible, which=which, **kwargs)
#    3195         if axis in ['y', 'both']:
#    3196             self.yaxis.grid(visible, which=which, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in grid(self, visible, which, **kwargs)
#    1658             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1659                                 if visible is None else visible)
# -> 1660             self.set_tick_params(which='major', **gridkw)
#    1661         self.stale = True
#    1662
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kwargs)
#     930         """
#     931         _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 932         kwtrans = self._translate_tick_params(kwargs)
#     933
#     934         # the kwargs are stored in self._major/minor_tick_kw so that any
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in _translate_tick_params(kw, reverse)
#    1074         for key in kw_:
#    1075             if key not in allowed_keys:
# -> 1076                 raise ValueError(
#    1077                     "keyword %s is not recognized; valid keywords are %s"
#    1078                     % (key, allowed_keys))
#
# ValueError: keyword grid_b is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
# create data
values=np.cumsum(np.random.randn(1000,1))
# use the plot function
plt.plot(values)

# %%
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.cumsum.html
a = np.array([[1,2,3], [4,5,6]])
print(a)
np.cumsum(a)
np.cumsum(a,axis=0)
# Out:
# [[1 2 3]
#  [4 5 6]]
# array([[1, 2, 3],
#        [5, 7, 9]])

# %%
# Data
df=pd.DataFrame({'x': range(1,11), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(1,11), 'y3': np.random.randn(10)+range(11,21) })

# multiple line plot
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
plt.legend(loc='upper center')
# Out:
# <ipython-input-15-7fd3559b52a8>:5: RuntimeWarning: Second argument 'y1' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
# <ipython-input-15-7fd3559b52a8>:6: RuntimeWarning: Second argument 'y2' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
# <ipython-input-15-7fd3559b52a8>:7: RuntimeWarning: Second argument 'y3' is ambiguous: could be a format string but is in 'data'; using as data.  If it was intended as data, set the format string to an empty string to suppress this warning.  If it was intended as a format string, explicitly pass the x-values as well.  Alternatively, rename the entry in 'data'.
#   plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")

# %%
# Loading the data from an URL
url = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url)
movies.head()
# Out:
#    Unnamed: 0                 title    title_type   genre  runtime  \
# 0           1           Filly Brown  Feature Film   Drama     80.0
# 1           2              The Dish  Feature Film   Drama    101.0
# 2           3   Waiting for Guffman  Feature Film  Comedy     84.0
# 3           4  The Age of Innocence  Feature Film   Drama    139.0
# 4           5           Malevolence  Feature Film  Horror     90.0
#
#   mpaa_rating                    studio  thtr_rel_year  thtr_rel_month  \
# 0           R       Indomina Media Inc.           2013               4
# 1       PG-13     Warner Bros. Pictures           2001               3
# 2           R    Sony Pictures Classics           1996               8
# 3          PG         Columbia Pictures           1993              10
# 4           R  Anchor Bay Entertainment           2004               9
#
#    thtr_rel_day  ...  best_actor_win  best_actress_win  best_dir_win  \
# 0            19  ...              no                no            no
# 1            14  ...              no                no            no
# 2            21  ...              no                no            no
# 3             1  ...             yes                no           yes
# 4            10  ...              no                no            no
#
#    top200_box           director             actor1              actor2  \
# 0          no   Michael D. Olmos     Gina Rodriguez        Jenni Rivera
# 1          no          Rob Sitch          Sam Neill    Kevin Harrington
# 2          no  Christopher Guest  Christopher Guest    Catherine O'Hara
# 3          no    Martin Scorsese   Daniel Day-Lewis   Michelle Pfeiffer
# 4          no        Stevan Mena      Samantha Dark  R. Brandon Johnson
#
#                  actor3            actor4               actor5
# 0  Lou Diamond Phillips     Emilio Rivera  Joseph Julian Soria
# 1     Patrick Warburton          Tom Long       Genevieve Mooy
# 2          Parker Posey       Eugene Levy          Bob Balaban
# 3          Winona Ryder  Richard E. Grant         Alec McCowen
# 4       Brandon Johnson     Heather Magee       Richard Glover
#
# [5 rows x 31 columns]

# %%
# use the function regplot to make a scatterplot with regression line
# sns.set(color_codes=True)
sns.regplot(x = movies["critics_score"],
            y = movies["audience_score"], ci = 95) # ci = None will not display the confidence interval

# Without regression fit:
# sns.regplot(x=movies["critics_score"],
#             y = movies["audience_score"],
#             fit_reg=False)
# Out:
# <Axes: xlabel='critics_score', ylabel='audience_score'>

# %%
# Another example to show the confidence interval
# https://www.mathsisfun.com/data/confidence-interval.html
tips = sns.load_dataset("tips")
# tips.head()
sns.regplot(x="total_bill", y="tip", data=tips, ci = None)
# sns.regplot(x="total_bill", y="tip", data=tips)
# sns.regplot(x="total_bill", y="tip", data=tips, ci = 95)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x = movies["critics_score"],
            y = movies["audience_score"],
            marker="+", fit_reg=False)
# Out:
# <Axes: xlabel='critics_score', ylabel='audience_score'>

# %%
sns.regplot(x = movies["critics_score"],
            y = movies["audience_score"],
            marker="+", fit_reg=False, color='red')
# Out:
# <Axes: xlabel='critics_score', ylabel='audience_score'>

# %%
sns.regplot(x = movies["critics_score"],
            y = movies["audience_score"],
            marker="+", fit_reg=False, scatter_kws={"color":"red", "alpha":0.5, "s":100})
# Out:
# <Axes: xlabel='critics_score', ylabel='audience_score'>

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x = "critics_score",
            y = "audience_score", data = movies, fit_reg=False, hue='genre', legend=False)

# Move the legend (labeling of plot) to an empty part of the plot
plt.legend(loc='lower right')

# %%
df = sns.load_dataset('iris')

# Use the 'hue' argument to provide a factor variable
sns.lmplot(x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False)

# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
# https://python-graph-gallery.com/violin-plot/
# Violinplots allow to visualize the distribution of a numeric variable for one or several groups.
# It is really close from a boxplot, but allows a deeper understanding of the density.
# Violins are particularly adapted when the amount of data is huge and showing individual observations gets impossible.
# Violinplots probably deserve more attention compared to boxplot that can sometimes hide features of the data.

# If you have only one numerical variable, you probably better have to make an histogram or a density plot.
# But you can still use the violinplot function to describe the distribution of this variable, as follow:
# from pylab import *
df = sns.load_dataset('iris')

# plot
sns.violinplot(x=df["species"], y=df["sepal_length"])
# sns.boxplot(x="species", y="sepal_length", data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
# plot of 2 variables
# Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable
p1=sns.kdeplot(df['sepal_width'], shade=True, color="r")
p1=sns.kdeplot(df['sepal_length'], shade=True, color="b")
# Out:
# <ipython-input-25-593e83d6776b>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   p1=sns.kdeplot(df['sepal_width'], shade=True, color="r")
# <ipython-input-25-593e83d6776b>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   p1=sns.kdeplot(df['sepal_length'], shade=True, color="b")
